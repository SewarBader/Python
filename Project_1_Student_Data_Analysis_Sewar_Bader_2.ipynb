# %% [markdown]
# <a href="https://colab.research.google.com/github/SewarBader/Python/blob/main/Project_1_Student_Data_Analysis_Sewar_Bader_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Student Data Analysis**
#
#
# ---
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **For the given student_data.txt file do the following:**

# %% [markdown]
# 1. Read data from **student_data.txt** file:
#
#     Each line in the file contains a student's name followed by their marks.
#
# 2. Save data in a dictionary:
#
#     Key: Student name
#     Value: List of marks
#
# 3. Perform the following calculations without using built-in functions (e.g., sum(), max(), min(), avg(), sort()):
#
#     > Use math functions like pow() and sqrt() where necessary.
#
#     > Organize the code into functions.
#
#     > Use exception handling to manage errors.
#
#
# 4. Calculate and store the following information in an output dictionary:
#
#     4.1-  Maximum average with student name
#
#     4.2- Maximum mark with student name
#
#     4.3-  Minimum average with student name
#
#     4.4-  Minimum mark with student name
#
#     4.5-  Standard deviation of the highest two averages
#
#     4.6-  First quartile (Q1) for the best student
#
#     4.7-  Second quartile (Median or Q2) for the best student
#
#     4.8-  Third quartile (Q3) for the best student
#
#     4.9-  Interquartile Range (IQR) for the best student
#
#     4.10-  Most frequent mark
#
# 5. Export the output dictionary to a JSON file.

# %%
# Read data from student_data.txt file:
# Each line in the file contains a student's name followed by their marks.

with open('student_data.txt','r') as file:
  content= file.read()
  print("the file content is:")
  print(content)
# Out:
# the file content is:
# Mahmoud, 96, 99, 100, 99, 97, 95, 98
# Mohammad, 54, 98, 57, 78, 54, 75, 84, 70
# Ali, 56, 51, 93, 77, 83, 59, 82, 80
# Susu, 98, 66, 78, 72, 99, 97, 89, 69
# Omar, 89, 52, 92, 81, 87, 84, 74, 57
# Ahmed, 59, 60, 60, 63, 60, 61, 77, 74
# Aisha, 95, 75, 61, 74, 99, 79, 59, 75
# Hana, 81, 69, 81, 66, 95, 89, 78, 90
# Fatima, 98, 90, 67, 89, 69, 57, 86, 61
# Hassan, 76, 82, 85, 79, 96, 64, 74, 53
# Layla, 84, 63, 82, 72, 82, 68, 92, 95
# Youssef, 73, 98, 71, 100, 71, 71, 50, 55
# Khalid, 80, 84, 86, 80, 60, 60, 88, 85
# Mariam, 52, 75, 53, 93, 60, 73, 75, 60
# Ibrahim, 97, 92, 97, 50, 96, 80, 77, 70
# Noura, 51, 54, 55, 51, 86, 53, 69, 65
# Zaid, 90, 83, 98, 98, 79, 97, 87, 73
# Aya, 80, 61, 78, 99, 84, 96, 56, 91
# Reem, 99, 88, 82, 55, 87, 74, 82, 93
# Lina, 50, 97, 94, 82, 81, 58, 54, 65
# Sara, 67, 92, 71, 66, 84, 58, 55, 94
# Jana, 95, 98, 100, 62, 73, 56, 87, 53
# Salma, 68, 87, 95, 67, 75, 72, 51, 93
# Mona, 59, 84, 57, 77, 60, 100, 84, 69
# ...

# %%
# Save data in a dictionary:
# Key: Student name Value: List of mark
from string import digits
import re
dictionary={}

with open('student_data.txt','r') as file:
  content= file.read().split('\n')
  for cont in content:
    cont=cont.split(',')
    key=cont[0]
    val=cont[1:]
    dictionary[key]=val

print(dictionary)
# Out:
# {'Mahmoud': [' 96', ' 99', ' 100', ' 99', ' 97', ' 95', ' 98'], 'Mohammad': [' 54', ' 98', ' 57', ' 78', ' 54', ' 75', ' 84', ' 70'], 'Ali': [' 56', ' 51', ' 93', ' 77', ' 83', ' 59', ' 82', ' 80'], 'Susu': [' 98', ' 66', ' 78', ' 72', ' 99', ' 97', ' 89', ' 69'], 'Omar': [' 89', ' 52', ' 92', ' 81', ' 87', ' 84', ' 74', ' 57'], 'Ahmed': [' 59', ' 60', ' 60', ' 63', ' 60', ' 61', ' 77', ' 74'], 'Aisha': [' 95', ' 75', ' 61', ' 74', ' 99', ' 79', ' 59', ' 75'], 'Hana': [' 81', ' 69', ' 81', ' 66', ' 95', ' 89', ' 78', ' 90'], 'Fatima': [' 98', ' 90', ' 67', ' 89', ' 69', ' 57', ' 86', ' 61'], 'Hassan': [' 76', ' 82', ' 85', ' 79', ' 96', ' 64', ' 74', ' 53'], 'Layla': [' 84', ' 63', ' 82', ' 72', ' 82', ' 68', ' 92', ' 95'], 'Youssef': [' 73', ' 98', ' 71', ' 100', ' 71', ' 71', ' 50', ' 55'], 'Khalid': [' 80', ' 84', ' 86', ' 80', ' 60', ' 60', ' 88', ' 85'], 'Mariam': [' 52', ' 75', ' 53', ' 93', ' 60', ' 73', ' 75', ' 60'], 'Ibrahim': [' 97', ' 92', ' 97', ' 50', ' 96', ' 80', ' 77
# ...

# %%
# Dictionary output

dict_output = {

    "MaxValue": {
        "student_name": "",
        "value": ""
    },
    "MaxAvg": {
        "student_name": "",
        "value": ""
    },

    "MinValue": {
        "student_name": "",
        "value": ""
    },
    "MinAvg": {
        "student_name": "",
        "value": ""
    },

    "standard_deviation": "",
    "Q1": "",
    "Q2": "",
    "Q3": "",
    "IQR": "",
    "most_freq_value": ""

}

# %%
# Question4
# 4.1- Maximum average with student name
listt=[]
Max_Avg = 0
max_student = ""

def MaxAverage(sum,number):
  global Max_Avg, max_student
  Avg=sum/number
  listt.append((student,Avg))
  if Avg>Max_Avg:
    Max_Avg=Avg
    max_student=student
  # print(Max_Avg)

for student, marks in dictionary.items():
  sum_marks = 0
  count=0
  for mark in marks:
    count=count+1
    sum_marks += int(mark)
  # Avg=sum_marks/count
  MaxAverage(sum_marks,count)
print(f"{max_student} has the Max Average: {Max_Avg}")
dict_output["MaxAvg"]["student_name"]=max_student
dict_output["MaxAvg"]["value"]=Max_Avg
print(dict_output)
# Out:
# Mahmoud has the Max Average: 97.71428571428571
# {'MaxValue': {'student_name': 'Mahmoud', 'value': 100}, 'MaxAvg': {'student_name': 'Mahmoud', 'value': 97.71428571428571}, 'MinValue': {'student_name': 'Youssef', 'value': 50}, 'MinAvg': {'student_name': '', 'value': 100}, 'standard_deviation': 4.794642857142854, 'Q1': 96, 'Q2': 98, 'Q3': 99, 'IQR': 3, 'most_freq_value': 60}

# %%
#Question
# 4.3- Minimum average with student name
listt=[]
Min_Avg =100
min_student = ""

def MaxAverage(sum,number):
  global Min_Avg, min_student
  Avg=sum/number
  listt.append((student,Avg))
  if Avg<Min_Avg:
    Min_Avg=Avg
    min_student=student
  # print(Max_Avg)
def MaxAverage2(sum_marks):
  for student, marks in dictionary.items():
    sum_marks = 0
    count=0
    for mark in marks:
     count=count+1
    sum_marks += int(mark)
  # Avg=sum_marks/count
  MaxAverage(sum_marks,count)
print(f"{min_student} has the Min Average: {Min_Avg}")
dict_output["MinAvg"]["student_name"]=min_student
dict_output["MinAvg"]["value"]=Min_Avg
print(dict_output)
# Out:
#  has the Min Average: 100
# {'MaxValue': {'student_name': 'Mahmoud', 'value': 100}, 'MaxAvg': {'student_name': 'Mahmoud', 'value': 97.71428571428571}, 'MinValue': {'student_name': 'Youssef', 'value': 50}, 'MinAvg': {'student_name': '', 'value': 100}, 'standard_deviation': 4.794642857142854, 'Q1': 96, 'Q2': 98, 'Q3': 99, 'IQR': 3, 'most_freq_value': 60}

# %%
# 4.2- Maximum mark with student name
Max_Value=0
list2=[]
max_student=[]
for student, marks in dictionary.items():
  for mark in marks:
    X=int(mark)
    list2.append((student,X))
    if X>Max_Value:
      Max_Value=X
      max_student=student
    # elif X == Max_Value:
    #   max_student.append(student)
print(f"{max_student} has a max mark {Max_Value}")
dict_output["MaxValue"]["student_name"]=max_student
dict_output["MaxValue"]["value"]=Max_Value
print(dict_output)
# Out:
# Mahmoud has a max mark 100
# {'MaxValue': {'student_name': 'Mahmoud', 'value': 100}, 'MaxAvg': {'student_name': 'Mahmoud', 'value': 97.71428571428571}, 'MinValue': {'student_name': 'Youssef', 'value': 50}, 'MinAvg': {'student_name': '', 'value': 100}, 'standard_deviation': 4.794642857142854, 'Q1': 96, 'Q2': 98, 'Q3': 99, 'IQR': 3, 'most_freq_value': 60}

# %%
# 4.4- Minimum mark with student name
Min_Value=100
list3=[]
min_student=[]
for student, marks in dictionary.items():
  for mark in marks:
    Y=int(mark)
    list3.append((student,Y))
    if Y<Min_Value:
      Min_Value=Y
      min_student=student
    # elif X == Max_Value:
    #   max_student.append(student)
print(f"{min_student} has a min mark {Min_Value}")
dict_output["MinValue"]["student_name"]=min_student
dict_output["MinValue"]["value"]=Min_Value
print(dict_output)
# Out:
# Youssef has a min mark 50
# {'MaxValue': {'student_name': 'Mahmoud', 'value': 100}, 'MaxAvg': {'student_name': 'Mahmoud', 'value': 97.71428571428571}, 'MinValue': {'student_name': 'Youssef', 'value': 50}, 'MinAvg': {'student_name': '', 'value': 100}, 'standard_deviation': 4.794642857142854, 'Q1': 96, 'Q2': 98, 'Q3': 99, 'IQR': 3, 'most_freq_value': 60}

# %%
# Question4
# 4.5- Standard deviation of the highest two averages
import math
import statistics
listt=[]
First_Max_Avg = 0
second_Max_Avg=0
First_max_student = ""

def MaxAverage1(sum,number):
  global First_Max_Avg, First_max_student,second_Max_Avg,second_max_student
  Avg=sum/number
  listt.append((student,Avg))
  if Avg > First_Max_Avg:
        # Update second highest before replacing the highest
        second_Max_Avg = First_Max_Avg
        second_max_student = First_max_student

        First_Max_Avg = Avg
        First_max_student = student
  elif Avg > second_Max_Avg:
       second_Max_Avg = Avg
       second_max_student = student



for student, marks in dictionary.items():
  sum_marks = 0
  count=0
  for mark in marks:
    count=count+1
    sum_marks += int(mark)
  # Avg=sum_marks/count
  MaxAverage1(sum_marks,count)
print(f"{First_max_student} has the Max Average: {First_Max_Avg}, and {second_max_student} has second max average:{second_Max_Avg}")
mean=(First_Max_Avg+second_Max_Avg)/2
standard_deviation_FMA=math.sqrt(((math.pow((First_Max_Avg-mean),2))+math.pow((second_Max_Avg-mean),2))/2)
# print(standard_deviation_FMA)
dict_output["standard_deviation"]=standard_deviation_FMA
print(dict_output)
# Out:
# Mahmoud has the Max Average: 97.71428571428571, and Zaid has second max average:88.125
# {'MaxValue': {'student_name': 'Mahmoud', 'value': 100}, 'MaxAvg': {'student_name': 'Mahmoud', 'value': 97.71428571428571}, 'MinValue': {'student_name': 'Youssef', 'value': 50}, 'MinAvg': {'student_name': '', 'value': 100}, 'standard_deviation': 4.794642857142854, 'Q1': 96, 'Q2': 98, 'Q3': 99, 'IQR': 3, 'most_freq_value': 60}

# %%
# 4.6- First quartile (Q1) for the best student


# find best student
# listt=[]
# Max_Avg = 0
# max_student = ""

# def MaxAverage(sum,number):
#   global Max_Avg, max_student
#   Avg=sum/number
#   listt.append((student,Avg))
#   if Avg>Max_Avg:
#     Max_Avg=Avg
#     max_student=student

# for student, marks in dictionary.items():
#   sum_marks = 0
#   count=0
#   for mark in marks:
#     count=count+1
#     sum_marks += int(mark)
#   # Avg=sum_marks/count
#   MaxAverage(sum_marks,count)


list3=[]
for markk in dictionary[max_student]:
   list3.append(int(markk))
   list3.sort()
print(f"{max_student} has the Max Average: {Max_Avg} and the marks is{list3} ")
Q1=int(1+(len(list3))/4)
print(Q1)
print(list3[Q1-1])
dict_output["Q1"]=list3[Q1-1]
print(dict_output)
# Out:
# Mahmoud has the Max Average: 97.71428571428571 and the marks is[95, 96, 97, 98, 99, 99, 100]
# 2
# 96
# {'MaxValue': {'student_name': 'Mahmoud', 'value': 100}, 'MaxAvg': {'student_name': 'Mahmoud', 'value': 97.71428571428571}, 'MinValue': {'student_name': 'Youssef', 'value': 50}, 'MinAvg': {'student_name': '', 'value': 100}, 'standard_deviation': 4.794642857142854, 'Q1': 96, 'Q2': 98, 'Q3': 99, 'IQR': 3, 'most_freq_value': 60}

# %%
# 4.7- Second quartile (Median or Q2) for the best student
list3=[]
for markk in dictionary[max_student]:
   list3.append(int(markk))
   list3.sort()
print(f"{max_student} has the Max Average: {Max_Avg} and the marks is{list3} ")
if (len(list3)) %2!=0:
  X=int((len(list3))/2)
  print(X)
  median=list3[X]
elif (len(list3)) %2==0:
    X1 = int(len(list3) / 2)-1
    X2 = int(len(list3) / 2)
    median = (list3[X1] + list3[X2]) / 2
    print(median)
dict_output["Q2"]=median
print(dict_output)
# Out:
# Mahmoud has the Max Average: 97.71428571428571 and the marks is[95, 96, 97, 98, 99, 99, 100]
# 3
# {'MaxValue': {'student_name': 'Mahmoud', 'value': 100}, 'MaxAvg': {'student_name': 'Mahmoud', 'value': 97.71428571428571}, 'MinValue': {'student_name': 'Youssef', 'value': 50}, 'MinAvg': {'student_name': '', 'value': 100}, 'standard_deviation': 4.794642857142854, 'Q1': 96, 'Q2': 98, 'Q3': 99, 'IQR': 3, 'most_freq_value': 60}

# %%
# 4.8- Third quartile (Q3) for the best student

list3=[]
for markk in dictionary[max_student]:
   list3.append(int(markk))
list3.sort()
# print(f"{max_student} has the Max Average: {Max_Avg} and the marks is{list3} ")
Q3=[]
if (len(list3)) %2!=0:
  Q3=list3[-X:]
  print(Q3)
  if (len(Q3))%2!=0:
     print((len(Q3)))
     Y=int(((len(Q3))/2))
     print(Y)
     median=Q3[Y]
     print(median)
  else:
     X1 = int(len(Q3) / 2)-1
     X2 = int(len(Q3) / 2)
     median = (Q3[X1] + Q3[X2]) / 2
     print(median)

elif (len(list3)) %2==0:
    Q3=list3[X:]
    print(Q3)
    if (len(Q3))%2!=0:
     print((len(Q3)))
     Y=int(((len(Q3))/2))
     print(Y)
     median=Q3[Y]
     print(median)
    else:
     X1 = int(len(Q3) / 2)-1
     X2 = int(len(Q3) / 2)
     median = (Q3[X1] + Q3[X2]) / 2
     print(median)
dict_output["Q3"]=median
print(dict_output)
# Out:
# [99, 99, 100]
# 3
# 1
# 99
# {'MaxValue': {'student_name': 'Mahmoud', 'value': 100}, 'MaxAvg': {'student_name': 'Mahmoud', 'value': 97.71428571428571}, 'MinValue': {'student_name': 'Youssef', 'value': 50}, 'MinAvg': {'student_name': '', 'value': 100}, 'standard_deviation': 4.794642857142854, 'Q1': 96, 'Q2': 98, 'Q3': 99, 'IQR': 3, 'most_freq_value': 60}

# %%
# 4.9- Interquartile Range (IQR) for the best student
IQR=dict_output["Q3"] - dict_output["Q1"]
print(dict_output["Q3"])
print(dict_output["Q1"])
print(IQR)
dict_output["IQR"]=IQR
print(dict_output)
# Out:
# 99
# 96
# 3
# {'MaxValue': {'student_name': 'Mahmoud', 'value': 100}, 'MaxAvg': {'student_name': 'Mahmoud', 'value': 97.71428571428571}, 'MinValue': {'student_name': 'Youssef', 'value': 50}, 'MinAvg': {'student_name': '', 'value': 100}, 'standard_deviation': 4.794642857142854, 'Q1': 96, 'Q2': 98, 'Q3': 99, 'IQR': 3, 'most_freq_value': 60}

# %%
# 4.10- Most frequent mark
frequent_mark = ""
Most_frequency_mark = 0
list0=[]
for marks in dictionary.values():
  for mark in marks:
    list0.append(mark)
    if list0.count(mark)>Most_frequency_mark:
       Most_frequency_mark=list0.count(mark)
       frequent_mark=mark
print(frequent_mark)
print( Most_frequency_mark)
dict_output["most_freq_value"]=int(frequent_mark)
print(dict_output)
# listr=[]
# count = 0
# for marks in dictionary.values():
#    for marke in marks:
#      if int(marke)==60:
#        listr.append(marke)
#        count+=1
#      else:
#       continue
# print((len(listr)))
# Out:
#  60
# 21
# {'MaxValue': {'student_name': 'Mahmoud', 'value': 100}, 'MaxAvg': {'student_name': 'Mahmoud', 'value': 97.71428571428571}, 'MinValue': {'student_name': 'Youssef', 'value': 50}, 'MinAvg': {'student_name': '', 'value': 100}, 'standard_deviation': 4.794642857142854, 'Q1': 96, 'Q2': 98, 'Q3': 99, 'IQR': 3, 'most_freq_value': 60}

# %%
print(dict_output)
# Out:
# {'MaxValue': {'student_name': 'Mahmoud', 'value': 100}, 'MaxAvg': {'student_name': 'Mahmoud', 'value': 97.71428571428571}, 'MinValue': {'student_name': 'Youssef', 'value': 50}, 'MinAvg': {'student_name': '', 'value': 100}, 'standard_deviation': 4.794642857142854, 'Q1': 96, 'Q2': 98, 'Q3': 99, 'IQR': 3, 'most_freq_value': 60}

# %%
#  5.Export the output dictionary to a JSON file.
import json

new_file_json="jsonDictionary.json"
with open(new_file_json, 'w') as file:
  json.dump(dict_output, file, indent=2)
print(f"Dictionary has been exported to {new_file_json}")
# Out:
# Dictionary has been exported to jsonDictionary.json

# %% [markdown]
# # **The End**
#
#
# ---
#
# ![image.png](data:image/png;base64,...)
